# %%
import pandas as pd
# !pip install xlrd==1.2.0

# %%
import xlrd
data = pd.read_excel("resumeITFair (2).xlsx")
data
# Out:
#                                                    Data1  \
# 0      13;"917287031144053";"documents/b17b320ce9ade8...
# 1      15;"503068122699786";"documents/584bd78a8e7896...
# 2      16;"959545483152525";"documents/dc79b58c6903ac...
# 3      17;"916030675272394";"documents/c4fae69bddca86...
# 4      18;"326172308423515";"documents/200be20dabdb89...
# ...                                                  ...
# 11009  12033;"888ab3ae61288e88429f1ad6d786";"document...
# 11010  12034;"6a642ee66382f2e9f5da5383ce5d";"document...
# 11011  12035;"493f86b5947ba42854348c4cfccb";"document...
# 11012  12036;"edwP5j7QTAcQkrtKCKHKkAJJuRM2";"document...
# 11013  12037;"a00af5e40ff86a5a2283e4c3a5a0";"document...
#
#                                                    Data2     Unnamed: 2  \
# 0      Tamil Nadu";"Male";"-";"-";"0";"0;0;0";"-";"NA...            NaN
# 1      Tamil Nadu";"Male";"-";"-";"0";"0;0;0";"-";"NA...            NaN
# ...

# %%
list_original = data['Data1'].to_list()

# %%
df = pd.read_csv("CVa_Done_Till_19th.csv")

# %%
edited_list = df['data1'].to_list()

# %%
len(list_original)
# Out:
# 11014

# %%
len(edited_list)
final_list = []

# %%
for item in edited_list:
    for name in list_original:
        if item==name:
            list_original.remove(item)

# %%
len(list_original)
# Out:
# 9085

# %%
new_df = pd.DataFrame(list_original)

# %%
new_df
# Out:
#                                                       0
# 0     13;"917287031144053";"documents/b17b320ce9ade8...
# 1     940;"mTLQyDnlXkbpmPSTy4nSjq8fPGV2";"documents/...
# 2     941;"CBsMnqoF8dYu9xtWZitQaV6rRBq1";"documents/...
# 3     945;"N5t3oHXKsqbqmKEUBpLHUp9RIsv2";"documents/...
# 4     951;"9Ly5gSK1KKfSKq3rDC3xQKYUaWC3";"documents/...
# ...                                                 ...
# 9080  12033;"888ab3ae61288e88429f1ad6d786";"document...
# 9081  12034;"6a642ee66382f2e9f5da5383ce5d";"document...
# 9082  12035;"493f86b5947ba42854348c4cfccb";"document...
# 9083  12036;"edwP5j7QTAcQkrtKCKHKkAJJuRM2";"document...
# 9084  12037;"a00af5e40ff86a5a2283e4c3a5a0";"document...
#
# [9085 rows x 1 columns]

# %%
new_df.to_csv("new_csv.csv")
