# %%
import pandas as pd
import xlrd

# %%
data = pd.read_excel("resumeITFair (1).xlsx")

# %%
data
# Out:
#                                                    data1  \
# 0      13;"917287031144053";"documents/b17b320ce9ade8...
# 1      15;"503068122699786";"documents/584bd78a8e7896...
# 2      16;"959545483152525";"documents/dc79b58c6903ac...
# 3      17;"916030675272394";"documents/c4fae69bddca86...
# 4      18;"326172308423515";"documents/200be20dabdb89...
# ...                                                  ...
# 11009  12033;"888ab3ae61288e88429f1ad6d786";"document...
# 11010  12034;"6a642ee66382f2e9f5da5383ce5d";"document...
# 11011  12035;"493f86b5947ba42854348c4cfccb";"document...
# 11012  12036;"edwP5j7QTAcQkrtKCKHKkAJJuRM2";"document...
# 11013  12037;"a00af5e40ff86a5a2283e4c3a5a0";"document...
#
#                                                    data2     Unnamed: 2  \
# 0      Tamil Nadu";"Male";"-";"-";"0";"0;0;0";"-";"NA...            NaN
# 1      Tamil Nadu";"Male";"-";"-";"0";"0;0;0";"-";"NA...            NaN
# ...

# %%
list1 = data['data1'].to_list()

# %%
list1
# Out:
# ['13;"917287031144053";"documents/b17b320ce9ade82da21d84b8f957634a.pdf";"2020-12-23 20:24:36";"Mohammed Yaseen ";"8111823788";"yaseen.pc@gmail.com";"Bachelors (B.Tech / BA / B.Sc)";"2020";"NA";"NA";"0";"6";"Chennai',
#  '15;"503068122699786";"documents/584bd78a8e78964f1e520a2f0ce5257b.pdf";"2020-12-23 20:31:20";"RISHABH THAKUR";"8826276352";"rishabh1599@gmail.com";"Bachelors (B.Tech / BA / B.Sc)";"2021";"NA";"NA";"0";"5";"Chennai',
#  '16;"959545483152525";"documents/dc79b58c6903acca7d3a39b994ad160b.pdf";"2020-12-23 20:42:42";"Suraj Gupta";"9773119183";"sg198374@gmail.com";"Bachelors (B.Tech / BA / B.Sc)";"2021";"NA";"NA";"0";"5";"Chennai',
#  '17;"916030675272394";"documents/c4fae69bddca86634de5cb16f13b27e9.pdf";"2020-12-23 20:49:12";"SALINI K.S";"8682873621";"saliniks.sivan@gmail.com";"Bachelors (B.Tech / BA / B.Sc)";"2021";"NA";"NA";"0";"5";"Chennai',
# ...

# %%
list2 = []
for item in list1:
    if 'documents' in str(item):
        list2.append(item)

# %%
list2
# Out:
# ['13;"917287031144053";"documents/b17b320ce9ade82da21d84b8f957634a.pdf";"2020-12-23 20:24:36";"Mohammed Yaseen ";"8111823788";"yaseen.pc@gmail.com";"Bachelors (B.Tech / BA / B.Sc)";"2020";"NA";"NA";"0";"6";"Chennai',
#  '15;"503068122699786";"documents/584bd78a8e78964f1e520a2f0ce5257b.pdf";"2020-12-23 20:31:20";"RISHABH THAKUR";"8826276352";"rishabh1599@gmail.com";"Bachelors (B.Tech / BA / B.Sc)";"2021";"NA";"NA";"0";"5";"Chennai',
#  '16;"959545483152525";"documents/dc79b58c6903acca7d3a39b994ad160b.pdf";"2020-12-23 20:42:42";"Suraj Gupta";"9773119183";"sg198374@gmail.com";"Bachelors (B.Tech / BA / B.Sc)";"2021";"NA";"NA";"0";"5";"Chennai',
#  '17;"916030675272394";"documents/c4fae69bddca86634de5cb16f13b27e9.pdf";"2020-12-23 20:49:12";"SALINI K.S";"8682873621";"saliniks.sivan@gmail.com";"Bachelors (B.Tech / BA / B.Sc)";"2021";"NA";"NA";"0";"5";"Chennai',
# ...

# %%
list3 = []
for items in list2:
    k = item.split(";")
    for items in k:
        if "documents" in items:
            list3.append(items)

# %%
list3
# Out:
# ['"documents/2935979b8617e43208e575a57e5d294e.pdf"',
#  '"documents/2935979b8617e43208e575a57e5d294e.pdf"',
#  '"documents/2935979b8617e43208e575a57e5d294e.pdf"',
#  '"documents/2935979b8617e43208e575a57e5d294e.pdf"',
#  '"documents/2935979b8617e43208e575a57e5d294e.pdf"',
#  '"documents/2935979b8617e43208e575a57e5d294e.pdf"',
#  '"documents/2935979b8617e43208e575a57e5d294e.pdf"',
#  '"documents/2935979b8617e43208e575a57e5d294e.pdf"',
#  '"documents/2935979b8617e43208e575a57e5d294e.pdf"',
#  '"documents/2935979b8617e43208e575a57e5d294e.pdf"',
#  '"documents/2935979b8617e43208e575a57e5d294e.pdf"',
#  '"documents/2935979b8617e43208e575a57e5d294e.pdf"',
#  '"documents/2935979b8617e43208e575a57e5d294e.pdf"',
#  '"documents/2935979b8617e43208e575a57e5d294e.pdf"',
#  '"documents/2935979b8617e43208e575a57e5d294e.pdf"',
#  '"documents/2935979b8617e43208e575a57e5d294e.pdf"',
#  '"documents/2935979b8617e43208e575a57e5d294e.pdf"',
#  '"documents/2935979b8617e43208e575a57e5d294e.pdf"',
# ...

# %%
list4 = []
for items in list3:
   list4.append( items[1:-1])

# %%
list4
# Out:
# ['documents/2935979b8617e43208e575a57e5d294e.pdf',
#  'documents/2935979b8617e43208e575a57e5d294e.pdf',
#  'documents/2935979b8617e43208e575a57e5d294e.pdf',
#  'documents/2935979b8617e43208e575a57e5d294e.pdf',
#  'documents/2935979b8617e43208e575a57e5d294e.pdf',
#  'documents/2935979b8617e43208e575a57e5d294e.pdf',
#  'documents/2935979b8617e43208e575a57e5d294e.pdf',
#  'documents/2935979b8617e43208e575a57e5d294e.pdf',
#  'documents/2935979b8617e43208e575a57e5d294e.pdf',
#  'documents/2935979b8617e43208e575a57e5d294e.pdf',
#  'documents/2935979b8617e43208e575a57e5d294e.pdf',
#  'documents/2935979b8617e43208e575a57e5d294e.pdf',
#  'documents/2935979b8617e43208e575a57e5d294e.pdf',
#  'documents/2935979b8617e43208e575a57e5d294e.pdf',
#  'documents/2935979b8617e43208e575a57e5d294e.pdf',
#  'documents/2935979b8617e43208e575a57e5d294e.pdf',
#  'documents/2935979b8617e43208e575a57e5d294e.pdf',
#  'documents/2935979b8617e43208e575a57e5d294e.pdf',
# ...

# %%
df = pd.DataFrame(list4)

# %%
df.columns = ['Path']

# %%
df
# Out:
#                                                  Path
# 0      documents/2935979b8617e43208e575a57e5d294e.pdf
# 1      documents/2935979b8617e43208e575a57e5d294e.pdf
# 2      documents/2935979b8617e43208e575a57e5d294e.pdf
# 3      documents/2935979b8617e43208e575a57e5d294e.pdf
# 4      documents/2935979b8617e43208e575a57e5d294e.pdf
# ...                                               ...
# 10929  documents/2935979b8617e43208e575a57e5d294e.pdf
# 10930  documents/2935979b8617e43208e575a57e5d294e.pdf
# 10931  documents/2935979b8617e43208e575a57e5d294e.pdf
# 10932  documents/2935979b8617e43208e575a57e5d294e.pdf
# 10933  documents/2935979b8617e43208e575a57e5d294e.pdf
#
# [10934 rows x 1 columns]

# %%
df.to_csv('Paths.csv')
